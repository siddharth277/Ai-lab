# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('residential_housing_updated.csv')
df
# Out:
#           Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0        1.0         NaN       RL         65.0   8450.0   Pave  Grvl
# 1        2.0        20.0       RL         80.0   9600.0   Pave  Grvl
# 2        3.0        60.0       RL         68.0  11250.0   Pave  Grvl
# 3        4.0        70.0       RL         60.0   9550.0   Pave  Grvl
# 4        5.0        60.0       RL         84.0  14260.0   Pave  Grvl
# ...      ...         ...      ...          ...      ...    ...   ...
# 1405  1456.0        60.0       RL         62.0   7917.0   Pave  Pave
# 1406  1457.0        20.0       RL         85.0  13175.0   Pave  Pave
# 1407  1458.0        70.0       RL         66.0      NaN   Pave  Pave
# 1408  1459.0        20.0       RL         68.0   9717.0   Pave  Pave
# 1409  1460.0        20.0       RL         75.0   9937.0   Pave  Pave
#
#      Utilities LandSlope Condition2  ... 3SsnPorch  ScreenPorch  PoolArea  \
# 0       AllPub       Gtl       Norm  ...       0.0          0.0       0.0
# 1       AllPub       Gtl       Norm  ...       0.0          0.0       0.0
# 2       AllPub       Gtl       Norm  ...       0.0          0.0       0.0
# 3       AllPub       Gtl       Norm  ...       0.0          0.0       0.0
# 4       AllPub       Gtl       Norm  ...       0.0          NaN       0.0
# ...        ...       ...        ...  ...       ...          ...       ...
# 1405    AllPub       Gtl       Norm  ...       0.0          0.0       NaN
# 1406    AllPub       Gtl       Norm  ...       0.0          0.0       NaN
# 1407    AllPub       Gtl       Norm  ...       0.0          0.0       0.0
# 1408    AllPub       Gtl       Norm  ...       0.0          0.0       0.0
# 1409    AllPub       Gtl       Norm  ...       0.0          0.0       0.0
#
#       PoolQC  MiscVal MoSold  YrSold SaleType SaleCondition SalePrice
# 0         Ex      0.0    2.0     NaN       WD        Normal  208500.0
# 1         Ex      0.0    5.0  2007.0       WD        Normal  181500.0
# 2         Ex      0.0    9.0  2008.0       WD        Normal  223500.0
# 3         Ex      0.0    2.0  2006.0       WD       Abnorml  140000.0
# 4         Ex      0.0   12.0  2008.0       WD        Normal  250000.0
# ...      ...      ...    ...     ...      ...           ...       ...
# 1405      Gd      0.0    NaN  2007.0       WD        Normal  175000.0
# 1406      Gd      0.0    2.0  2010.0       WD        Normal  210000.0
# 1407      Gd   2500.0    5.0  2010.0       WD        Normal  266500.0
# 1408      Gd      0.0    4.0  2010.0       WD        Normal  142125.0
# 1409      Gd      0.0    6.0  2008.0       WD        Normal  147500.0
#
# [1410 rows x 60 columns]

# %%
missing_per_column = df.isna().sum()
total_missing = missing_per_column.sum()

print(missing_per_column)
print("Total missing values:", total_missing)
# Out:
# Id                 0
# MSSubClass       140
# MSZoning           0
# LotFrontage      369
# LotArea          125
# Street             0
# Alley              0
# Utilities          0
# LandSlope          0
# Condition2         0
# BldgType           0
# OverallQual       75
# OverallCond      139
# YearBuilt         97
# YearRemodAdd      95
# RoofMatl           0
# MasVnrArea       114
# ExterQual          0
# Foundation         0
# BsmtQual           0
# BsmtCond           0
# BsmtExposure       0
# BsmtFinSF1        80
# BsmtFinSF2        96
# BsmtUnfSF         45
# TotalBsmtSF       80
# Heating            0
# CentralAir         0
# Electrical         0
# 1stFlrSF          98
# 2ndFlrSF          34
# LowQualFinSF      46
# GrLivArea         86
# BsmtFullBath     117
# BsmtHalfBath      71
# FullBath         113
# HalfBath          43
# BedroomAbvGr      29
# KitchenAbvGr      92
# TotRmsAbvGrd     100
# Fireplaces        47
# FireplaceQu        0
# GarageType         0
# GarageYrBlt      125
# GarageCars       119
# GarageArea        71
# GarageQual         0
# WoodDeckSF        65
# OpenPorchSF      109
# EnclosedPorch    101
# 3SsnPorch         49
# ScreenPorch      127
# PoolArea         142
# PoolQC             0
# MiscVal           57
# MoSold           111
# YrSold           136
# SaleType           0
# SaleCondition      0
# SalePrice          0
# dtype: int64
# Total missing values: 3543

# %%
numeric_columns = df.select_dtypes(include=['number']).columns
stats=df[numeric_columns].describe()
print(stats)
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1410.000000  1270.000000  1041.000000    1285.000000  1335.000000
# mean    728.860993    57.271654    69.793468   10561.186770     6.107116
# std     422.801301    42.677075    24.553368   10469.171396     1.374343
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     362.250000    20.000000    59.000000    7500.000000     5.000000
# 50%     727.500000    50.000000    69.000000    9453.000000     6.000000
# 75%    1096.500000    70.000000    80.000000   11600.000000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1271.000000  1313.000000   1315.000000  1296.000000  1330.000000  ...
# mean      5.568057  1971.283321   1984.438023   103.906636   441.384962  ...
# std       1.102561    30.176420     20.787314   184.049858   458.173776  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1966.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1993.000000     0.000000   384.000000  ...
# 75%       6.000000  2000.000000   2004.000000   164.000000   705.750000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1345.000000  1301.000000    1309.000000  1361.000000  1283.000000
# mean     95.112268    46.373559      21.675325     3.525349    14.540140
# std     125.975633    66.769894      60.852915    29.971523    55.278791
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    24.000000       0.000000     0.000000     0.000000
# 75%     168.000000    66.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1268.000000   1353.000000  1299.000000  1274.000000    1410.000000
# mean      2.318612     43.084996     6.317937  2007.828100  181157.942553
# std      37.329114    505.988633     2.705312     1.331046   79671.289524
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129900.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214800.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
numeric_columns = df.select_dtypes(include=['number']).columns

medians = df[numeric_columns].median()

df_filled_median = df.copy()
df_filled_median[numeric_columns] = df_filled_median[numeric_columns].fillna(medians)

print("Missing values replaced by the median of their respective attributes.")
print(df_filled_median.head())  
print("\nNumber of missing values in each attribute after replacement:")
print(df_filled_median.isnull().sum())
# Out:
# Missing values replaced by the median of their respective attributes.
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley Utilities  \
# 0  1.0        50.0       RL         65.0   8450.0   Pave  Grvl    AllPub
# 1  2.0        20.0       RL         80.0   9600.0   Pave  Grvl    AllPub
# 2  3.0        60.0       RL         68.0  11250.0   Pave  Grvl    AllPub
# 3  4.0        70.0       RL         60.0   9550.0   Pave  Grvl    AllPub
# 4  5.0        60.0       RL         84.0  14260.0   Pave  Grvl    AllPub
#
#   LandSlope Condition2  ... 3SsnPorch  ScreenPorch  PoolArea  PoolQC  MiscVal  \
# 0       Gtl       Norm  ...       0.0          0.0       0.0      Ex      0.0
# 1       Gtl       Norm  ...       0.0          0.0       0.0      Ex      0.0
# 2       Gtl       Norm  ...       0.0          0.0       0.0      Ex      0.0
# 3       Gtl       Norm  ...       0.0          0.0       0.0      Ex      0.0
# 4       Gtl       Norm  ...       0.0          0.0       0.0      Ex      0.0
#
#   MoSold  YrSold SaleType SaleCondition SalePrice
# 0    2.0  2008.0       WD        Normal  208500.0
# 1    5.0  2007.0       WD        Normal  181500.0
# 2    9.0  2008.0       WD        Normal  223500.0
# 3    2.0  2006.0       WD       Abnorml  140000.0
# 4   12.0  2008.0       WD        Normal  250000.0
#
# [5 rows x 60 columns]
#
# Number of missing values in each attribute after replacement:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# Alley            0
# Utilities        0
# LandSlope        0
# Condition2       0
# BldgType         0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofMatl         0
# MasVnrArea       0
# ExterQual        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# FireplaceQu      0
# GarageType       0
# GarageYrBlt      0
# GarageCars       0
# GarageArea       0
# GarageQual       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# PoolQC           0
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# dtype: int64

# %%
df_processed = df_filled_median  


processed_stats = df_processed.describe().transpose()
processed_stats['Mode'] = df_processed.mode().iloc[0]

print(processed_stats['mean'], processed_stats['50%'], processed_stats['Mode'],processed_stats['std'])
# Out:
# Id                  728.860993
# MSSubClass           56.549645
# LotFrontage          69.585816
# LotArea           10462.943262
# OverallQual           6.101418
# OverallCond           5.512057
# YearBuilt          1971.401418
# YearRemodAdd       1985.014894
# MasVnrArea           95.505674
# BsmtFinSF1          438.129078
# BsmtFinSF2           42.146099
# BsmtUnfSF           567.540426
# TotalBsmtSF        1056.379433
# 1stFlrSF           1156.121277
# 2ndFlrSF            340.112057
# LowQualFinSF          6.051773
# GrLivArea          1514.787943
# BsmtFullBath          0.386525
# BsmtHalfBath          0.054610
# FullBath              1.602837
# HalfBath              0.371631
# BedroomAbvGr          2.868085
# KitchenAbvGr          1.042553
# TotRmsAbvGrd          6.469504
# Fireplaces            0.628369
# GarageYrBlt        1978.692908
# GarageCars            1.778723
# GarageArea          471.814894
# WoodDeckSF           90.727660
# OpenPorchSF          44.643972
# EnclosedPorch        20.122695
# 3SsnPorch             3.402837
# ScreenPorch          13.230496
# PoolArea              2.085106
# MiscVal              41.343262
# MoSold                6.292908
# YrSold             2007.844681
# SalePrice        181157.942553
# Name: mean, dtype: float64 Id                  727.5
# MSSubClass           50.0
# LotFrontage          69.0
# LotArea            9453.0
# OverallQual           6.0
# OverallCond           5.0
# YearBuilt          1973.0
# YearRemodAdd       1993.0
# MasVnrArea            0.0
# BsmtFinSF1          384.0
# BsmtFinSF2            0.0
# BsmtUnfSF           479.0
# TotalBsmtSF         990.5
# 1stFlrSF           1086.0
# 2ndFlrSF              0.0
# LowQualFinSF          0.0
# GrLivArea          1464.0
# BsmtFullBath          0.0
# BsmtHalfBath          0.0
# FullBath              2.0
# HalfBath              0.0
# BedroomAbvGr          3.0
# KitchenAbvGr          1.0
# TotRmsAbvGrd          6.0
# Fireplaces            1.0
# GarageYrBlt        1980.0
# GarageCars            2.0
# GarageArea          479.0
# WoodDeckSF            0.0
# OpenPorchSF          24.0
# EnclosedPorch         0.0
# 3SsnPorch             0.0
# ScreenPorch           0.0
# PoolArea              0.0
# MiscVal               0.0
# MoSold                6.0
# YrSold             2008.0
# SalePrice        163000.0
# Name: 50%, dtype: float64 Id                  427.0
# MSSubClass           20.0
# LotFrontage          69.0
# LotArea            9453.0
# OverallQual           6.0
# OverallCond           5.0
# YearBuilt          1973.0
# YearRemodAdd       1950.0
# MasVnrArea            0.0
# BsmtFinSF1            0.0
# BsmtFinSF2            0.0
# BsmtUnfSF             0.0
# TotalBsmtSF         990.5
# 1stFlrSF           1086.0
# 2ndFlrSF              0.0
# LowQualFinSF          0.0
# GrLivArea          1464.0
# BsmtFullBath          0.0
# BsmtHalfBath          0.0
# FullBath              2.0
# HalfBath              0.0
# BedroomAbvGr          3.0
# KitchenAbvGr          1.0
# TotRmsAbvGrd          6.0
# Fireplaces            1.0
# GarageYrBlt        1980.0
# GarageCars            2.0
# GarageArea            0.0
# WoodDeckSF            0.0
# OpenPorchSF           0.0
# EnclosedPorch         0.0
# 3SsnPorch             0.0
# ScreenPorch           0.0
# PoolArea              0.0
# MiscVal               0.0
# MoSold                6.0
# YrSold             2008.0
# SalePrice        140000.0
# Name: Mode, dtype: object Id                 422.801301
# MSSubClass          40.559772
# LotFrontage         21.097531
# LotArea           9998.965829
# OverallQual          1.337481
# OverallCond          1.060382
# YearBuilt           29.122423
# YearRemodAdd        20.188795
# MasVnrArea         178.707969
# BsmtFinSF1         445.174777
# BsmtFinSF2         153.944429
# BsmtUnfSF          438.137044
# TotalBsmtSF        431.856980
# 1stFlrSF           373.373853
# 2ndFlrSF           434.949820
# LowQualFinSF        49.465599
# GrLivArea          517.664659
# BsmtFullBath         0.508511
# BsmtHalfBath         0.230399
# FullBath             0.543096
# HalfBath             0.497877
# BedroomAbvGr         0.797202
# KitchenAbvGr         0.208831
# TotRmsAbvGrd         1.560966
# Fireplaces           0.638967
# GarageYrBlt         23.382887
# GarageCars           0.722232
# GarageArea         209.176978
# WoodDeckSF         124.642847
# OpenPorchSF         64.413218
# EnclosedPorch       58.897354
# 3SsnPorch           29.452843
# ScreenPorch         52.892865
# PoolArea            35.405025
# MiscVal            495.720974
# MoSold               2.597978
# YrSold               1.266197
# SalePrice        79671.289524
# Name: std, dtype: float64

# %%
df_filled_propagated = df.fillna(method='ffill')

print("DataFrame after forward filling missing values:")
print(df_filled_propagated.head())

missing_values_count = df_filled_propagated.isnull().sum().sum()
print(f"Total number of missing values after forward filling: {missing_values_count}")
# Out:
# DataFrame after forward filling missing values:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley Utilities  \
# 0  1.0         NaN       RL         65.0   8450.0   Pave  Grvl    AllPub
# 1  2.0        20.0       RL         80.0   9600.0   Pave  Grvl    AllPub
# 2  3.0        60.0       RL         68.0  11250.0   Pave  Grvl    AllPub
# 3  4.0        70.0       RL         60.0   9550.0   Pave  Grvl    AllPub
# 4  5.0        60.0       RL         84.0  14260.0   Pave  Grvl    AllPub
#
#   LandSlope Condition2  ... 3SsnPorch  ScreenPorch  PoolArea  PoolQC  MiscVal  \
# 0       Gtl       Norm  ...       0.0          0.0       0.0      Ex      0.0
# 1       Gtl       Norm  ...       0.0          0.0       0.0      Ex      0.0
# 2       Gtl       Norm  ...       0.0          0.0       0.0      Ex      0.0
# 3       Gtl       Norm  ...       0.0          0.0       0.0      Ex      0.0
# 4       Gtl       Norm  ...       0.0          0.0       0.0      Ex      0.0
#
#   MoSold  YrSold SaleType SaleCondition SalePrice
# 0    2.0     NaN       WD        Normal  208500.0
# 1    5.0  2007.0       WD        Normal  181500.0
# 2    9.0  2008.0       WD        Normal  223500.0
# 3    2.0  2006.0       WD       Abnorml  140000.0
# 4   12.0  2008.0       WD        Normal  250000.0
#
# [5 rows x 60 columns]
# Total number of missing values after forward filling: 5

# %%
df_bfilled_propagated = df.fillna(method='bfill')

print("DataFrame after backward filling missing values:")
print(df_bfilled_propagated.head())

missing_values_count2 = df_bfilled_propagated.isnull().sum().sum()
print(f"Total number of missing values after backward filling: {missing_values_count2}")
# Out:
# DataFrame after backward filling missing values:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley Utilities  \
# 0  1.0        20.0       RL         65.0   8450.0   Pave  Grvl    AllPub
# 1  2.0        20.0       RL         80.0   9600.0   Pave  Grvl    AllPub
# 2  3.0        60.0       RL         68.0  11250.0   Pave  Grvl    AllPub
# 3  4.0        70.0       RL         60.0   9550.0   Pave  Grvl    AllPub
# 4  5.0        60.0       RL         84.0  14260.0   Pave  Grvl    AllPub
#
#   LandSlope Condition2  ... 3SsnPorch  ScreenPorch  PoolArea  PoolQC  MiscVal  \
# 0       Gtl       Norm  ...       0.0          0.0       0.0      Ex      0.0
# 1       Gtl       Norm  ...       0.0          0.0       0.0      Ex      0.0
# 2       Gtl       Norm  ...       0.0          0.0       0.0      Ex      0.0
# 3       Gtl       Norm  ...       0.0          0.0       0.0      Ex      0.0
# 4       Gtl       Norm  ...       0.0          0.0       0.0      Ex      0.0
#
#   MoSold  YrSold SaleType SaleCondition SalePrice
# 0    2.0  2007.0       WD        Normal  208500.0
# 1    5.0  2007.0       WD        Normal  181500.0
# 2    9.0  2008.0       WD        Normal  223500.0
# 3    2.0  2006.0       WD       Abnorml  140000.0
# 4   12.0  2008.0       WD        Normal  250000.0
#
# [5 rows x 60 columns]
# Total number of missing values after backward filling: 0

# %%
df_filled_propagated.isnull().sum()
# Out:
# Id               0
# MSSubClass       1
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# Alley            0
# Utilities        0
# LandSlope        0
# Condition2       0
# BldgType         0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofMatl         0
# MasVnrArea       1
# ExterQual        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     1
# KitchenAbvGr     0
# TotRmsAbvGrd     1
# Fireplaces       0
# FireplaceQu      0
# GarageType       0
# GarageYrBlt      0
# GarageCars       0
# GarageArea       0
# GarageQual       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# PoolQC           0
# MiscVal          0
# MoSold           0
# YrSold           1
# SaleType         0
# SaleCondition    0
# SalePrice        0
# dtype: int64

# %%
df_interpolated = df.interpolate(method='linear', axis=0)

print("DataFrame after linear interpolation:")
print(df_interpolated.head())

missing_values_count = df_interpolated.isnull().sum().sum()
print(f"Total number of missing values after linear interpolation: {missing_values_count}")
# Out:
# DataFrame after linear interpolation:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley Utilities  \
# 0  1.0         NaN       RL         65.0   8450.0   Pave  Grvl    AllPub
# 1  2.0        20.0       RL         80.0   9600.0   Pave  Grvl    AllPub
# 2  3.0        60.0       RL         68.0  11250.0   Pave  Grvl    AllPub
# 3  4.0        70.0       RL         60.0   9550.0   Pave  Grvl    AllPub
# 4  5.0        60.0       RL         84.0  14260.0   Pave  Grvl    AllPub
#
#   LandSlope Condition2  ... 3SsnPorch  ScreenPorch  PoolArea  PoolQC  MiscVal  \
# 0       Gtl       Norm  ...       0.0          0.0       0.0      Ex      0.0
# 1       Gtl       Norm  ...       0.0          0.0       0.0      Ex      0.0
# 2       Gtl       Norm  ...       0.0          0.0       0.0      Ex      0.0
# 3       Gtl       Norm  ...       0.0          0.0       0.0      Ex      0.0
# 4       Gtl       Norm  ...       0.0          0.0       0.0      Ex      0.0
#
#   MoSold  YrSold SaleType SaleCondition SalePrice
# 0    2.0     NaN       WD        Normal  208500.0
# 1    5.0  2007.0       WD        Normal  181500.0
# 2    9.0  2008.0       WD        Normal  223500.0
# 3    2.0  2006.0       WD       Abnorml  140000.0
# 4   12.0  2008.0       WD        Normal  250000.0
#
# [5 rows x 60 columns]
# Total number of missing values after linear interpolation: 5

# %%
df_interpolated.isnull().sum()
# Out:
# Id               0
# MSSubClass       1
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# Alley            0
# Utilities        0
# LandSlope        0
# Condition2       0
# BldgType         0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofMatl         0
# MasVnrArea       1
# ExterQual        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     1
# KitchenAbvGr     0
# TotRmsAbvGrd     1
# Fireplaces       0
# FireplaceQu      0
# GarageType       0
# GarageYrBlt      0
# GarageCars       0
# GarageArea       0
# GarageQual       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# PoolQC           0
# MiscVal          0
# MoSold           0
# YrSold           1
# SaleType         0
# SaleCondition    0
# SalePrice        0
# dtype: int64
