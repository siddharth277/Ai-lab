# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /home/user/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
data=pd.read_csv("residential_housing.csv")

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
count=0
for i in data["LotArea"]:
    if i>2000:
        count = count +1
print (count)
# Out:
# 1435

# %%
count=0
for i in data["BedroomAbvGr"]:
    if i==3:
        count = count +1
print (count)
# Out:
# 804

# %%
i=0
while i<10:
      print("lootarea:", i+1, data['LotArea'][i])
      i=i+1
# Out:
# lootarea: 1 8450
# lootarea: 2 9600
# lootarea: 3 11250
# lootarea: 4 9550
# lootarea: 5 14260
# lootarea: 6 14115
# lootarea: 7 10084
# lootarea: 8 10382
# lootarea: 9 6120
# lootarea: 10 7420

# %%
i=0
saleprice=0
while i<15:
      saleprice=saleprice + data["SalePrice"][i]
      i=i+1
print(saleprice)
# Out:
# 2956400

# %%
lootarea_list = list(data['LotArea'].head(10))
print("lootarea list", lootarea_list)
print("Maximum :", max(lootarea_list))
print("Minimum :", min(lootarea_list))
# Out:
# lootarea list [8450, 9600, 11250, 9550, 14260, 14115, 10084, 10382, 6120, 7420]
# Maximum : 14260
# Minimum : 6120

# %%
i=0
saleprice=[]
for i in data["BedroomAbvGr"]:
    if i ==3:
        saleprice.append(data["SalePrice"][i])
print(saleprice)
# Out:
# [140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 140000, 14000
# ...

# %%
tuple1 = list(zip(data["LotArea"].head(5), data["SalePrice"].head(5)))
print("Tuple is:", tuple1)
# Out:
# Tuple is: [(8450, 208500), (9600, 181500), (11250, 223500), (9550, 140000), (14260, 250000)]

# %%
lootarea_dict = {}

for i in range(5):
    lootarea_dict[data["LotArea"][i]] = data["SalePrice"][i]

print("lootarea Dictionary:", lootarea_dict)
# Out:
# lootarea Dictionary: {8450: 208500, 9600: 181500, 11250: 223500, 9550: 140000, 14260: 250000}

# %%
avg_saleprice = np.mean(data["SalePrice"].values)
print("Average Price:", avg_saleprice)
# Out:
# Average Price: 180921.19589041095

# %%
min_LotArea = np.min(data["LotArea"].values)
max_LotArea = np.max(data["LotArea"].values)

print("Minimum LotArea:", min_LotArea)
print("Maximum LotArea:", max_LotArea)
# Out:
# Minimum LotArea: 1300
# Maximum LotArea: 215245

# %%
idx = np.argmax(data["SalePrice"].values)
print("highest salsprice:\n", data.iloc[idx])
# Out:
# highest salsprice:
#  Id                  692
# MSSubClass           60
# MSZoning             RL
# LotFrontage       104.0
# LotArea           21535
#                   ...
# MoSold                1
# YrSold             2007
# SaleType             WD
# SaleCondition    Normal
# SalePrice        755000
# Name: 691, Length: 81, dtype: object

# %%
expensive_idx = np.where(data["GrLivArea"].values > 2000)
data.loc[expensive_idx].head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# 20  21          60       RL        101.0    14215   Pave   NaN      IR1
# 35  36          60       RL        108.0    13418   Pave   NaN      Reg
#
#    LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 4          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 7          Lvl    AllPub  ...        0    NaN   NaN        Shed     350
# 11         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 20         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 35         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#    MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
top_SalePrice = np.sort(data["SalePrice"].values)[-10:][::-1]
print("Top 10 SalePrice:", top_SalePrice)
# Out:
# Top 10 SalePrice: [755000 745000 625000 611657 582933 556581 555000 538000 501837 485000]

# %%
Neighborhood_types = np.unique(data["Neighborhood"].values)
print("Neighborhood Types:", Neighborhood_types)
# Out:
# Neighborhood Types: ['Blmngtn' 'Blueste' 'BrDale' 'BrkSide' 'ClearCr' 'CollgCr' 'Crawfor'
#  'Edwards' 'Gilbert' 'IDOTRR' 'MeadowV' 'Mitchel' 'NAmes' 'NPkVill'
#  'NWAmes' 'NoRidge' 'NridgHt' 'OldTown' 'SWISU' 'Sawyer' 'SawyerW'
#  'Somerst' 'StoneBr' 'Timber' 'Veenker']

# %%
values = np.linspace(np.min(data["YearBuilt"].values),  np.max(data["YearBuilt"].values), 5) 
print("Generated values:", values)
# Out:
# Generated values: [1872.  1906.5 1941.  1975.5 2010. ]

# %%
std_GarageArea = np.std(data["GarageArea"].values)
print("std GarageArea:", std_GarageArea)
# Out:
# std GarageArea: 213.73160807515626

# %%
large_idx = np.where(data["LotArea"].values > 10000)
data.loc[large_idx].head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 5         Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 6         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 7         Lvl    AllPub  ...        0    NaN    NaN        Shed     350
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 2      9   2008        WD         Normal     223500
# ...

# %%
Data_df = pd.DataFrame(data)
Data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
Data_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
sortarr = np.sort(data["SalePrice"])
sortarr.head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 2
#       1 sortarr = np.sort(data["SalePrice"])
# ----> 2 sortarr.head(5)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
count=0 
for i in data["YearBuilt"]:
    if i>2000:
        count=count+1
print(count)
# Out:
# 364

# %%
#problem statement 2

# %%
data2=pd.read_csv("noshowappointments.csv")

# %%
data2
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
count=0
for i in data2["SMS_received"]:
    if i==1:
        count = count +1 
print (count)
# Out:
# 35482

# %%
count=0
for i in data2["Hipertension"]:
    if i==1:
        count = count +1 
print (count)
# Out:
# 21801

# %%
i=0
while i<10:
      print("Age:", i+1, data2['Age'][i])
      i=i+1
# Out:
# Age: 1 62
# Age: 2 56
# Age: 3 62
# Age: 4 8
# Age: 5 56
# Age: 6 76
# Age: 7 23
# Age: 8 39
# Age: 9 21
# Age: 10 19

# %%
i=0
Agesum=0
while i<15:
      Agesum=Agesum + (data2["Age"][i])
      i=i+1
print(Agesum)
# Out:
# 585

# %%
Age_list = list(data2['Age'].head(10))
print("Age list", lootarea_list)
print("Maximum :", max(Age_list))
print("Minimum :", min(Age_list))
# Out:
# Age list [8450, 9600, 11250, 9550, 14260, 14115, 10084, 10382, 6120, 7420]
# Maximum : 76
# Minimum : 8

# %%
tuple1 = list(zip(data2["Age"].head(5), data2["SMS_received"].head(5)))
print("Tuple is:", tuple1)
# Out:
# Tuple is: [(62, 0), (56, 0), (62, 0), (8, 0), (56, 0)]

# %%
dictionary={}

# %%
median_age = np.median(data2["Age"].values)
print("median age:", median_age)
# Out:
# median age: 37.0

# %%
variance = np.var(data2["Age"].values)
print("variance age:", variance)
# Out:
# variance age: 534.0767413267181

# %%
Neighborhood_types = np.unique(data2["Neighbourhood"].values)
print("Neighborhood Types:", Neighborhood_types)
# Out:
# Neighborhood Types: ['AEROPORTO' 'ANDORINHAS' 'ANTÔNIO HONÓRIO' 'ARIOVALDO FAVALESSA'
#  'BARRO VERMELHO' 'BELA VISTA' 'BENTO FERREIRA' 'BOA VISTA' 'BONFIM'
#  'CARATOÍRA' 'CENTRO' 'COMDUSA' 'CONQUISTA' 'CONSOLAÇÃO' 'CRUZAMENTO'
#  'DA PENHA' 'DE LOURDES' 'DO CABRAL' 'DO MOSCOSO' 'DO QUADRO'
#  'ENSEADA DO SUÁ' 'ESTRELINHA' 'FONTE GRANDE' 'FORTE SÃO JOÃO' 'FRADINHOS'
#  'GOIABEIRAS' 'GRANDE VITÓRIA' 'GURIGICA' 'HORTO' 'ILHA DAS CAIEIRAS'
#  'ILHA DE SANTA MARIA' 'ILHA DO BOI' 'ILHA DO FRADE' 'ILHA DO PRÍNCIPE'
#  'ILHAS OCEÂNICAS DE TRINDADE' 'INHANGUETÁ' 'ITARARÉ' 'JABOUR'
#  'JARDIM CAMBURI' 'JARDIM DA PENHA' 'JESUS DE NAZARETH' 'JOANA D´ARC'
#  'JUCUTUQUARA' 'MARIA ORTIZ' 'MARUÍPE' 'MATA DA PRAIA' 'MONTE BELO'
#  'MORADA DE CAMBURI' 'MÁRIO CYPRESTE' 'NAZARETH' 'NOVA PALESTINA'
#  'PARQUE INDUSTRIAL' 'PARQUE MOSCOSO' 'PIEDADE' 'PONTAL DE CAMBURI'
#  'PRAIA DO CANTO' 'PRAIA DO SUÁ' 'REDENÇÃO' 'REPÚBLICA' 'RESISTÊNCIA'
# ...

# %%
values = np.linspace(np.min(data2["Age"].values),  np.max(data2["Age"].values), 5) 
print("Generated values:", values)
# Out:
# Generated values: [ -1.  28.  57.  86. 115.]

# %%
Data_df = pd.DataFrame(data2)
Data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB
